# %%
#important he libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

# %% [markdown]
# # K-Means

# %%
#loading data
airline = pd.read_excel("C:/Users/SANJAY/Desktop/ExcelR/Assignments/Assignment - 7/Clustering/EastWestAirlines.xlsx",'data')
airline.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline2=airline.drop(['ID#'],axis=1)
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
airline2_norm=pd.DataFrame(normalize(airline2),columns=airline2.columns)
airline2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(airline2_norm)
    wcss.append(kmeans.inertia_)
    
#Elbow graph   
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Build Cluster algorithm using K=4
clusters4=KMeans(4,random_state=30).fit(airline2_norm)
clusters4
# Out:
# KMeans(n_clusters=4, random_state=30)

# %%
clusters4.labels_
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
airline4=airline2.copy()
airline4['clusters4id']=clusters4.labels_
airline4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
clusters4.cluster_centers_
# Out:
# array([[9.82878899e-01, 3.71612347e-03, 4.15057209e-05, 3.77179195e-05,
#         3.76205578e-05, 8.06914054e-02, 1.57453088e-04, 6.65079627e-03,
#         2.12921781e-05, 1.03324885e-01, 4.81770304e-06],
#        [5.23653977e-01, 2.37603195e-03, 9.13653056e-05, 4.56081254e-05,
#         4.45095230e-05, 7.97866700e-01, 5.07019477e-04, 1.75075997e-02,
#         5.89123100e-05, 1.31443994e-01, 3.00837174e-05],
#        [6.28081328e-01, 9.30359261e-04, 2.06331617e-04, 2.06128767e-04,
#         2.05879951e-04, 1.23980626e-01, 4.76413717e-04, 6.66146530e-03,
#         2.24385615e-05, 6.89106611e-01, 2.58980762e-05],
#        [8.99048678e-01, 2.03403471e-03, 5.68074076e-05, 3.01913199e-05,
#         2.95156437e-05, 4.03089039e-01, 4.02398112e-04, 7.62262675e-03,
#         2.24052643e-05, 8.50654942e-02, 9.73901648e-06]])

# %%
airline4.groupby('clusters4id').agg(['mean']).reset_index()
# Out:
#   clusters4id       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# 0           0  88484.857577  175.062961  1.495441  1.008250  1.001737
# 1           1  28617.579670  112.000000  3.280220  1.030220  1.068681
# 2           2   5129.247934    8.285124  1.004132  1.004132  1.000000
# 3           3  72378.903670  119.606422  3.077982  1.024771  1.018349
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   8110.131568    8.770734        476.973079        1.439427
# 1  42166.565934   17.634615        659.725275        1.909341
# 2    891.388430    3.012397         66.466942        0.194215
# 3  31486.477982   17.476147        445.017431        1.317431
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       4060.013895  0.255319
# 1       4229.689560  0.901099
# 2       4843.239669  0.185950
# ...

# %%
#plotting
plt.figure(figsize=(10, 7))  
plt.scatter(airline4['clusters4id'],airline4['Balance'], c=clusters4.labels_)

# %% [markdown]
# # DBSCAN

# %%
airline1 = pd.read_excel("C:/Users/SANJAY/Desktop/ExcelR/Assignments/Assignment - 7/Clustering/EastWestAirlines.xlsx",'data')
airline1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline1.drop(['ID#'],axis=1,inplace=True)
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalization function 
airline1_norm=StandardScaler().fit_transform(airline1)
airline1_norm
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
#Create DBscan cluster 
dbscan=DBSCAN(eps=3,min_samples=4)
dbscan.fit(airline1_norm)
# Out:
# DBSCAN(eps=3, min_samples=4)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
airline1['clusters']=dbscan.labels_
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline1.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean         mean      mean      mean      mean
# 0       -1  322569.694915  1486.966102  2.983051  1.084746  1.627119
# 1        0   70113.122402   125.374134  2.053118  1.000000  1.000000
# 2        1   45781.714286     0.000000  1.000000  3.000000  1.000000
# 3        2   39187.040000     0.000000  1.120000  2.000000  1.000000
# 4        3  112159.750000     0.000000  4.250000  1.000000  4.000000
#
#      Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#             mean        mean              mean            mean
# 0   73630.711864   31.084746       5133.118644       13.542373
# 1   16231.896074   11.247883        391.203233        1.192456
# 2   20147.571429   16.928571        410.000000        1.714286
# 3   11107.040000   14.840000        224.000000        0.800000
# 4  100646.750000   30.250000        262.500000        0.750000
#
#   Days_since_enroll    Award?
# ...

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(airline1['clusters'],airline1['Balance'], c=dbscan.labels_)

# %% [markdown]
# # Hierarchical Clustering

# %%
air_line = pd.read_excel("C:/Users/SANJAY/Desktop/ExcelR/Assignments/Assignment - 7/Clustering/EastWestAirlines.xlsx",'data')
air_line.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
air_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air_line=air_line.drop(['ID#'],axis=1)
air_line
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalize heterogenous numerical data using z-score (x-mean/std) or custom defined function 
# Normalization function - here custom defined
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame 
air_line_norm = norm_func(air_line)
air_line_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Create Dendrograms
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(air_line_norm,'complete'))

# %%
# create clusters
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(air_line_norm),columns=['clustersid'])
y
# Out:
#       clustersid
# 0              1
# 1              1
# 2              1
# 3              1
# 4              3
# ...          ...
# 3994           0
# 3995           0
# 3996           0
# 3997           4
# 3998           4
#
# [3999 rows x 1 columns]

# %%
y['clustersid'].value_counts()
# Out:
# 1    1011
# 0     946
# 2     808
# 4     699
# 3     535
# Name: clustersid, dtype: int64

# %%
# Adding clusters to dataset
air_line['clustersid']=hclusters.labels_
air_line
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
air_line.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# 0          0   79848.233615  285.097252  1.699789  1.024313  1.000000
# 1          1   43313.653808   21.506429  1.000000  1.033630  1.000989
# 2          2  106221.111386  161.262376  3.198020  1.001238  1.025990
# 3          3  127475.028037  160.801869  4.362617  1.000000  1.050467
# 4          4   30013.416309   98.054363  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  12079.774841   12.133192        781.939746        2.369979
# 1   2562.614243    5.474777        169.510386        0.523244
# 2  26458.257426   16.363861        198.733911        0.558168
# 3  58656.919626   22.235514        991.110280        3.005607
# 4   2552.569385    6.101574        340.274678        0.948498
#
#   Days_since_enroll Award?
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(air_line['clustersid'],air_line['Balance'], c=hclusters.labels_)
